# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN','NAME'], axis=1)
application_df.columns
# Out:
# Index(['APPLICATION_TYPE', 'AFFILIATION', 'CLASSIFICATION', 'USE_CASE',
#        'ORGANIZATION', 'STATUS', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS',
#        'ASK_AMT', 'IS_SUCCESSFUL'],
#       dtype='object')

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`

cutoff_value = 528
application_types_to_replace = application_df['APPLICATION_TYPE'].value_counts()[application_df['APPLICATION_TYPE'].value_counts() < cutoff_value].index

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
application_df['CLASSIFICATION'].value_counts()[application_df['CLASSIFICATION'].value_counts() > 1]
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`

cutoff_value = 1883
classifications_to_replace = application_df['CLASSIFICATION'].value_counts()[application_df['CLASSIFICATION'].value_counts() < cutoff_value].index

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df)
application_df.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                   False
# 1       1   108590              1                   False
# 2       1     5000              0                   False
# 3       1     6692              1                   False
# 4       1   142590              1                   False
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                  True                 False                False
# 1                 False                 False                 True
# 2                 False                 False                False
# 3                 False                 False                 True
# 4                 False                 False                 True
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                False                False                False  ...
# 1                False                False                False  ...
# 2                False                 True                False  ...
# 3                False                False                False  ...
# 4                False                False                False  ...
#
#    INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0              False                   False                     False
# 1               True                   False                     False
# 2              False                   False                     False
# 3              False                    True                     False
# 4              False                   False                      True
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0               False             False                   False
# 1               False             False                   False
# 2               False             False                   False
# 3               False             False                   False
# 4               False             False                   False
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0            False              False                      True
# 1            False              False                      True
# 2            False              False                      True
# 3            False              False                      True
# 4            False              False                      True
#
#    SPECIAL_CONSIDERATIONS_Y
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
#
# [5 rows x 44 columns]

# %%
# Split our preprocessed data into our features and target arrays
X = application_df.drop(columns=['IS_SUCCESSFUL'], axis=1)
y = application_df['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    random_state=1
                                                    )

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 50

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units = hidden_nodes_layer1, input_dim = number_input_features, activation = "relu" ))

# Add dropout regularization to the first hidden layer
nn.add(tf.keras.layers.Dropout(0.50))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                2200
#
#  dropout (Dropout)           (None, 50)                0
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 2251 (8.79 KB)
# Trainable params: 2251 (8.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 12s 7ms/step - loss: 0.6239 - accuracy: 0.6915
# Epoch 2/100
# 804/804 [==============================] - 6s 8ms/step - loss: 0.5859 - accuracy: 0.7179
# Epoch 3/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5771 - accuracy: 0.7220
# Epoch 4/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5717 - accuracy: 0.7254
# Epoch 5/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5705 - accuracy: 0.7266
# Epoch 6/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5673 - accuracy: 0.7276
# Epoch 7/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5652 - accuracy: 0.7275
# Epoch 8/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5670 - accuracy: 0.7260
# Epoch 9/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5648 - accuracy: 0.7266
# Epoch 10/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5637 - accuracy: 0.7282
# Epoch 11/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5639 - accuracy: 0.7282
# Epoch 12/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5642 - accuracy: 0.7297
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5625 - accuracy: 0.7282
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5637 - accuracy: 0.7284
# Epoch 15/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5616 - accuracy: 0.7301
# Epoch 16/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5605 - accuracy: 0.7292
# Epoch 17/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5597 - accuracy: 0.7287
# Epoch 18/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5601 - accuracy: 0.7293
# Epoch 19/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5611 - accuracy: 0.7286
# Epoch 20/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5612 - accuracy: 0.7285
# Epoch 21/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5603 - accuracy: 0.7285
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5606 - accuracy: 0.7291
# Epoch 23/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5602 - accuracy: 0.7287
# Epoch 24/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5621 - accuracy: 0.7297
# Epoch 25/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5604 - accuracy: 0.7297
# Epoch 26/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5596 - accuracy: 0.7316
# Epoch 27/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5580 - accuracy: 0.7317
# Epoch 28/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5591 - accuracy: 0.7288
# Epoch 29/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5583 - accuracy: 0.7289
# Epoch 30/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5587 - accuracy: 0.7311
# Epoch 31/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5618 - accuracy: 0.7289
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5580 - accuracy: 0.7309
# Epoch 33/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5593 - accuracy: 0.7304
# Epoch 34/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5582 - accuracy: 0.7298
# Epoch 35/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5588 - accuracy: 0.7302
# Epoch 36/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5589 - accuracy: 0.7307
# Epoch 37/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5565 - accuracy: 0.7291
# Epoch 38/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5579 - accuracy: 0.7293
# Epoch 39/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5588 - accuracy: 0.7297
# Epoch 40/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5581 - accuracy: 0.7304
# Epoch 41/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5561 - accuracy: 0.7294
# Epoch 42/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5584 - accuracy: 0.7301
# Epoch 43/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5575 - accuracy: 0.7318
# Epoch 44/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5596 - accuracy: 0.7297
# Epoch 45/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5565 - accuracy: 0.7300
# Epoch 46/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5554 - accuracy: 0.7303
# Epoch 47/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5576 - accuracy: 0.7303
# Epoch 48/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5570 - accuracy: 0.7308
# Epoch 49/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5572 - accuracy: 0.7304
# Epoch 50/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5579 - accuracy: 0.7312
# Epoch 51/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5561 - accuracy: 0.7300
# Epoch 52/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5575 - accuracy: 0.7319
# Epoch 53/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5584 - accuracy: 0.7301
# Epoch 54/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5555 - accuracy: 0.7310
# Epoch 55/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5583 - accuracy: 0.7306
# Epoch 56/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5588 - accuracy: 0.7315
# Epoch 57/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5572 - accuracy: 0.7306
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5577 - accuracy: 0.7317
# Epoch 59/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5562 - accuracy: 0.7315
# Epoch 60/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5570 - accuracy: 0.7321
# Epoch 61/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5581 - accuracy: 0.7304
# Epoch 62/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5567 - accuracy: 0.7322
# Epoch 63/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5580 - accuracy: 0.7289
# Epoch 64/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5595 - accuracy: 0.7313
# Epoch 65/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5563 - accuracy: 0.7304
# Epoch 66/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5572 - accuracy: 0.7305
# Epoch 67/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5580 - accuracy: 0.7320
# Epoch 68/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5571 - accuracy: 0.7292
# Epoch 69/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5569 - accuracy: 0.7303
# Epoch 70/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5559 - accuracy: 0.7322
# Epoch 71/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5561 - accuracy: 0.7305
# Epoch 72/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5558 - accuracy: 0.7307
# Epoch 73/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5551 - accuracy: 0.7296
# Epoch 74/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5566 - accuracy: 0.7312
# Epoch 75/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5570 - accuracy: 0.7325
# Epoch 76/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5561 - accuracy: 0.7290
# Epoch 77/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5544 - accuracy: 0.7305
# Epoch 78/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5567 - accuracy: 0.7313
# Epoch 79/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5564 - accuracy: 0.7315
# Epoch 80/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5555 - accuracy: 0.7318
# Epoch 81/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5552 - accuracy: 0.7310
# Epoch 82/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5568 - accuracy: 0.7303
# Epoch 83/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5570 - accuracy: 0.7331
# Epoch 84/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5566 - accuracy: 0.7306
# Epoch 85/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5562 - accuracy: 0.7323
# Epoch 86/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5557 - accuracy: 0.7319
# Epoch 87/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5567 - accuracy: 0.7322
# Epoch 88/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5549 - accuracy: 0.7299
# Epoch 89/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5543 - accuracy: 0.7320
# Epoch 90/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5561 - accuracy: 0.7325
# Epoch 91/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5562 - accuracy: 0.7322
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5561 - accuracy: 0.7310
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5560 - accuracy: 0.7306
# Epoch 94/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5562 - accuracy: 0.7329
# Epoch 95/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5561 - accuracy: 0.7311
# Epoch 96/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5558 - accuracy: 0.7310
# Epoch 97/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5540 - accuracy: 0.7316
# Epoch 98/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5556 - accuracy: 0.7310
# Epoch 99/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5552 - accuracy: 0.7308
# Epoch 100/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5546 - accuracy: 0.7321

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5530 - accuracy: 0.7308 - 649ms/epoch - 2ms/step
# Loss: 0.5529963374137878, Accuracy: 0.7308454513549805

# %%
# import matplotlib.pyplot
import matplotlib.pyplot as plt

# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history, index=range(1,len(fit_model.history["loss"])+1))

# Plot the accuracy
history_df.plot(y="accuracy")
plt.show()

# %%
# Export our model to HDF5 file
nn.save('Models/AlphabetSoupCharity_model5.h5')
